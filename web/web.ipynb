# %%
# 基本模块
import pandas as pd
from requests_html import HTMLSession

# %%
# 建构 参数模板  

参数_compTag_用户体验 = {'中国500强': {'init': ['-1'], 'headckid': ['58d828c357a8cb19'], 'flushckid': ['1'], 'fromSearchBtn': ['2'], 'keyword': ['用户体验'], 'compTag': ['155'], 'ckid': ['58d828c357a8cb19'], 'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['6aa779111c1b4ca77cff3648d9dee049'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['6aa779111c1b4ca77cff3648d9dee049']}, '2018互联网300强': {'init': ['-1'], 'headckid': ['58d828c357a8cb19'], 'flushckid': ['1'], 'fromSearchBtn': ['2'], 'keyword': ['用户体验'], 'compTag': ['182'], 'ckid': ['58d828c357a8cb19'], 'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['6aa779111c1b4ca77cff3648d9dee049'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['6aa779111c1b4ca77cff3648d9dee049']}, '制造业500强': {'init': ['-1'], 'headckid': ['58d828c357a8cb19'], 'flushckid': ['1'], 'fromSearchBtn': ['2'], 'keyword': ['用户体验'], 'compTag': ['186'], 'ckid': ['58d828c357a8cb19'], 'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['6aa779111c1b4ca77cff3648d9dee049'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['6aa779111c1b4ca77cff3648d9dee049']}, 'AI创新成长50强 ': {'init': ['-1'], 'headckid': ['58d828c357a8cb19'], 'flushckid': ['1'], 'fromSearchBtn': ['2'], 'keyword': ['用户体验'], 'compTag': ['189'], 'ckid': ['58d828c357a8cb19'], 'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['6aa779111c1b4ca77cff3648d9dee049'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['6aa779111c1b4ca77cff3648d9dee049']}, '独角兽': {'init': ['-1'], 'headckid': ['58d828c357a8cb19'], 'flushckid': ['1'], 'fromSearchBtn': ['2'], 'keyword': ['用户体验'], 'compTag': ['130'], 'ckid': ['58d828c357a8cb19'], 'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['6aa779111c1b4ca77cff3648d9dee049'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['6aa779111c1b4ca77cff3648d9dee049']}, '上市公司': {'init': ['-1'], 'headckid': ['58d828c357a8cb19'], 'flushckid': ['1'], 'fromSearchBtn': ['2'], 'keyword': ['用户体验'], 'compTag': ['156'], 'ckid': ['58d828c357a8cb19'], 'siTag': ['1B2M2Y8AsgTpgAmY7PhCfg~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['6aa779111c1b4ca77cff3648d9dee049'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['6aa779111c1b4ca77cff3648d9dee049']}}

# 多个页面准备测试1 中国500强
url = "https://www.liepin.com/zhaopin/" #想要爬取网页网址
session = HTMLSession()
payload = 参数_compTag_用户体验['2018互联网300强'] #参数compTag
r = session.get( url, params = payload)

# 单一页面爬+解析
session = HTMLSession()

def requests_liepin( url, params):
    r = session.get( url , params = payload)

    # 先取特定元素, 精准打击其子后辈
    主要元素 = r.html.xpath( '//ul[@class="sojob-list"]/li')

    # 作为xpath字典，键为我要名称，值为xpath
    dict_xpaths={ 
        'text': {
            '地区': '//div[contains(@class,"job-info")]/p/a',
            '公司名称': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
            'edu':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]',
            '经验':      '//div[contains(@class,"job-info")]/p/span[@class="edu"]/following-sibling::span',
            '薪水':    '//div[contains(@class,"job-info")]/p/span[@class="text-warning"]', 
            '时间':    '//div[contains(@class,"job-info")]/p/time/@title', 
            '职称':    '//div[contains(@class,"job-info")]/h3/a',   
        },
        'text_content': {
        },
        'href': {
            '链结':    '//div[contains(@class,"job-info")]/h3/a', 
            '公司URL': '//div[contains(@class,"sojob-item-main")]//p[@class="company-name"]/a', 
        }
    }

    def get_e_text_content(_xpath_):
        # 高级列表推导
        暂存结果 = [e.xpath(_xpath_)[0].lxml.text_content() for e in 主要元素]
        return(暂存结果)

    def get_e_text(_xpath_):
        # 高级列表推导
        暂存结果 = ["".join([x.strip() if type(x) is str else x.text.strip() for x in e.xpath(_xpath_)]) for e in 主要元素]
        return(暂存结果)

    def get_e_href(_xpath_):
        # 高级列表推导，“\”本行还未结束
        暂存结果 = [list(e.xpath(_xpath_, first=True).absolute_links)[0] \
                   if len(e.xpath(_xpath_, first=True).absolute_links) >= 1  \
                   else "" for e in 主要元素]
        return(暂存结果)

    # 只对主要元素下进行.xpath取值
    数据字典 = dict()

    数据字典 = {k:get_e_text_content(v) for k,v in dict_xpaths['text_content'].items()}
    数据字典.update({k:get_e_text(v) for k,v in dict_xpaths['text'].items()})
    数据字典.update({k:get_e_href(v) for k,v in dict_xpaths['href'].items()})

    数据 = pd.DataFrame(数据字典)
    #数据.to_excel("20春_Web数据挖掘_week03_liepin.xlsx", sheet_name="搜查结果")
    return (数据)


# 多个页面
url = "https://www.liepin.com/zhaopin/"

list_df = list()
for k,v in 参数_compTag_用户体验.items():
    payload = v
    df = requests_liepin( url, params = payload)
    df = df.assign (热门公司类型 = k)    
    list_df.append(df)

df_all = pd.concat(list_df)
df_all

# 输出为Excel表
df_all.to_excel("web_各热门公司类型.xlsx", sheet_name="搜查结果")

print (df_all.nunique())
df_all[['edu']].drop_duplicates()
df_all.groupby(['地区','经验']).agg({"职称":"count"}).sort_values(by='职称', ascending=False)
# Out:
# 地区         73
# 公司名称       64
# edu         6
# 经验          5
# 薪水         74
# 时间         21
# 职称        165
# 链结        187
# 公司URL      64
# 热门公司类型      6
# dtype: int64
#               职称
# 地区     经验
# 北京     3-5年   14
# 深圳-南山区 5-10年  10
#        3-5年    9
# 上海-张江  5-10年   9
# 北京     5-10年   8
# ...           ..
# 昆明     1-3年    1
# 昌吉     1-3年    1
# 曲靖     1-3年    1
# 杨凌     1-3年    1
# 黔西南    1-3年    1
#
# [100 rows x 1 columns]

# %%
url = "https://www.liepin.com/zhaopin/?compTag=182&key=UI设计师"
session = HTMLSession()
r = session.get( url )

# %%
# A-1  xpath 解析翻页a/@href-------一个页面的分页器对应的xpath
xpath_翻页a = '//div[@class="pagerbar"]/a' # 有disabled, current等href是javascript----所有的页码，包括上一页，下一页

xpath_翻页a = '//div[@class="pagerbar"]/a[starts-with(@href,"/zhaopin")]'#starts-with只要开头包含某个东西的链接我都要

print (r.html.xpath(xpath_翻页a)) 

href_列表 = [x.xpath('//@href')[0] for x in r.html.xpath(xpath_翻页a)]

文字_列表 = [x.text for x in r.html.xpath(xpath_翻页a)]  


href_字典 = {x.text:x.xpath('//@href')[0]  for x in r.html.xpath(xpath_翻页a)}  #字典，键是文字，值是链接
print (href_字典)
# Out:
# [<Element 'a' href='/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=1'>, <Element 'a' href='/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=2'>, <Element 'a' href='/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=3'>, <Element 'a' href='/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=4'>, <Element 'a' href='/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=1'>, <Element 'a' class=('last',) href='/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=4' title='末页'>]
# {'2': '/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=1', '3': '/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=2', '4': '/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=3', '5': '/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=4', '下一页': '/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=1', '': '/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=4'}

# %%
# A-2 建构参数模板：找到关键参数及参数结构

# 需要模组库
from urllib.parse import urlparse, parse_qs
import pandas as pd
from IPython.display import display, HTML

# 总体目标：输入 href_列表, 建构出参数字典

# urlparse 解析后丢入数据框，拆分URL
df = pd.DataFrame([ urlparse(x) for x in href_列表])
df_qs = pd.DataFrame([{k:v[0] for k,v in parse_qs(x).items()} for x in df['query'] ])

display(df)
print(df.nunique())
display(df_qs)
print(df_qs.nunique())

df_qs.curPage
df_qs = df_qs.assign (curPage_int=df_qs.curPage.astype(int)) # 变成整数
# Out:
#   scheme netloc       path params  \
# 0                /zhaopin/
# 1                /zhaopin/
# 2                /zhaopin/
# 3                /zhaopin/
# 4                /zhaopin/
# 5                /zhaopin/
#
#                                                query fragment
# 0  init=-1&headckid=e8331dd1649d08f6&fromSearchBt...
# 1  init=-1&headckid=e8331dd1649d08f6&fromSearchBt...
# 2  init=-1&headckid=e8331dd1649d08f6&fromSearchBt...
# 3  init=-1&headckid=e8331dd1649d08f6&fromSearchBt...
# 4  init=-1&headckid=e8331dd1649d08f6&fromSearchBt...
# 5  init=-1&headckid=e8331dd1649d08f6&fromSearchBt...
# scheme      1
# netloc      1
# path        1
# params      1
# query       4
# fragment    1
# dtype: int64
#   init          headckid fromSearchBtn compTag                         ckid  \
# 0   -1  e8331dd1649d08f6             2     182  e8331dd1649d08f6°radeFlag=0
# 1   -1  e8331dd1649d08f6             2     182  e8331dd1649d08f6°radeFlag=0
# 2   -1  e8331dd1649d08f6             2     182  e8331dd1649d08f6°radeFlag=0
# 3   -1  e8331dd1649d08f6             2     182  e8331dd1649d08f6°radeFlag=0
# 4   -1  e8331dd1649d08f6             2     182  e8331dd1649d08f6°radeFlag=0
# 5   -1  e8331dd1649d08f6             2     182  e8331dd1649d08f6°radeFlag=0
#
#      key                                          siTag         d_sfrom  \
# 0  UI设计师  RPxWkfDdUaIMSr7n63Qw6w~fA9rXquZc5IkJpXC-Ycixw  search_unknown
# 1  UI设计师  RPxWkfDdUaIMSr7n63Qw6w~fA9rXquZc5IkJpXC-Ycixw  search_unknown
# 2  UI设计师  RPxWkfDdUaIMSr7n63Qw6w~fA9rXquZc5IkJpXC-Ycixw  search_unknown
# 3  UI设计师  RPxWkfDdUaIMSr7n63Qw6w~fA9rXquZc5IkJpXC-Ycixw  search_unknown
# 4  UI设计师  RPxWkfDdUaIMSr7n63Qw6w~fA9rXquZc5IkJpXC-Ycixw  search_unknown
# 5  UI设计师  RPxWkfDdUaIMSr7n63Qw6w~fA9rXquZc5IkJpXC-Ycixw  search_unknown
#
#                              d_ckId d_curPage d_pageSize  \
# 0  0be7c1359b8501734be78e445ef13b0f         0         40
# 1  0be7c1359b8501734be78e445ef13b0f         0         40
# 2  0be7c1359b8501734be78e445ef13b0f         0         40
# 3  0be7c1359b8501734be78e445ef13b0f         0         40
# 4  0be7c1359b8501734be78e445ef13b0f         0         40
# 5  0be7c1359b8501734be78e445ef13b0f         0         40
#
#                            d_headId curPage
# 0  0be7c1359b8501734be78e445ef13b0f       1
# 1  0be7c1359b8501734be78e445ef13b0f       2
# 2  0be7c1359b8501734be78e445ef13b0f       3
# 3  0be7c1359b8501734be78e445ef13b0f       4
# 4  0be7c1359b8501734be78e445ef13b0f       1
# 5  0be7c1359b8501734be78e445ef13b0f       4
# init             1
# headckid         1
# fromSearchBtn    1
# compTag          1
# ckid             1
# key              1
# siTag            1
# d_sfrom          1
# d_ckId           1
# d_curPage        1
# d_pageSize       1
# d_headId         1
# curPage          4
# dtype: int64

# %%
# A-2 建构参数模板：找到关键参数及参数结构

def parse_url_qs_for_curPage (url):
    six_parts = urlparse(url) 
    out = parse_qs(six_parts.query)
    return (out)

# 取一例做模板
参数模板 = parse_url_qs_for_curPage(href_列表[0])
print (参数模板)

print (href_字典)
# Out:
# {'init': ['-1'], 'headckid': ['e8331dd1649d08f6'], 'fromSearchBtn': ['2'], 'compTag': ['182'], 'ckid': ['e8331dd1649d08f6°radeFlag=0'], 'key': ['UI设计师'], 'siTag': ['RPxWkfDdUaIMSr7n63Qw6w~fA9rXquZc5IkJpXC-Ycixw'], 'd_sfrom': ['search_unknown'], 'd_ckId': ['0be7c1359b8501734be78e445ef13b0f'], 'd_curPage': ['0'], 'd_pageSize': ['40'], 'd_headId': ['0be7c1359b8501734be78e445ef13b0f'], 'curPage': ['1']}
# {'2': '/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=1', '3': '/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=2', '4': '/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=3', '5': '/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=4', '下一页': '/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=1', '': '/zhaopin/?init=-1&headckid=e8331dd1649d08f6&fromSearchBtn=2&compTag=182&ckid=e8331dd1649d08f6°radeFlag=0&key=UI%E8%AE%BE%E8%AE%A1%E5%B8%88&siTag=RPxWkfDdUaIMSr7n63Qw6w%7EfA9rXquZc5IkJpXC-Ycixw&d_sfrom=search_unknown&d_ckId=0be7c1359b8501734be78e445ef13b0f&d_curPage=0&d_pageSize=40&d_headId=0be7c1359b8501734be78e445ef13b0f&curPage=4'}

# %%
# 建构参数模板生成器：keyword curPage comtag
def 参数模板生成(keyword, curPage,comtag):
    参数 = 参数模板.copy()
    参数['curPage'] = curPage
    参数['keyword'] = keyword
    参数['comtag'] = comtag
    return (参数)

参数_keyword_UI设计师_curPage = { 
    i:参数模板生成(curPage = [i], \
                  keyword = ['UI设计师'],\
                  comtag =['2018互联网300强']) \
    
   
    for i,v in href_字典.items()\
    }

print (df_qs.curPage_int.min()) 
print (df_qs.curPage_int.max()) 


参数_keyword_UI设计师_curPage = { 
    i:参数模板生成(curPage = [i], \
                  keyword = ['UI设计师'],\
                  comtag =['2018互联网300强']) \
    for i in range(0,df_qs.curPage_int.max()+1)\
    }
参数_keyword_UI设计师_curPage
# Out:
# 1
# 4
# {0: {'init': ['-1'],
#   'headckid': ['e8331dd1649d08f6'],
#   'fromSearchBtn': ['2'],
#   'compTag': ['182'],
#   'ckid': ['e8331dd1649d08f6°radeFlag=0'],
#   'key': ['UI设计师'],
#   'siTag': ['RPxWkfDdUaIMSr7n63Qw6w~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['0be7c1359b8501734be78e445ef13b0f'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['0be7c1359b8501734be78e445ef13b0f'],
#   'curPage': [0],
#   'keyword': ['UI设计师'],
#   'comtag': ['2018互联网300强']},
#  1: {'init': ['-1'],
#   'headckid': ['e8331dd1649d08f6'],
#   'fromSearchBtn': ['2'],
#   'compTag': ['182'],
#   'ckid': ['e8331dd1649d08f6°radeFlag=0'],
#   'key': ['UI设计师'],
#   'siTag': ['RPxWkfDdUaIMSr7n63Qw6w~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['0be7c1359b8501734be78e445ef13b0f'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['0be7c1359b8501734be78e445ef13b0f'],
#   'curPage': [1],
#   'keyword': ['UI设计师'],
#   'comtag': ['2018互联网300强']},
#  2: {'init': ['-1'],
#   'headckid': ['e8331dd1649d08f6'],
#   'fromSearchBtn': ['2'],
#   'compTag': ['182'],
#   'ckid': ['e8331dd1649d08f6°radeFlag=0'],
#   'key': ['UI设计师'],
#   'siTag': ['RPxWkfDdUaIMSr7n63Qw6w~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['0be7c1359b8501734be78e445ef13b0f'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['0be7c1359b8501734be78e445ef13b0f'],
#   'curPage': [2],
#   'keyword': ['UI设计师'],
#   'comtag': ['2018互联网300强']},
#  3: {'init': ['-1'],
#   'headckid': ['e8331dd1649d08f6'],
#   'fromSearchBtn': ['2'],
#   'compTag': ['182'],
#   'ckid': ['e8331dd1649d08f6°radeFlag=0'],
#   'key': ['UI设计师'],
#   'siTag': ['RPxWkfDdUaIMSr7n63Qw6w~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['0be7c1359b8501734be78e445ef13b0f'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['0be7c1359b8501734be78e445ef13b0f'],
#   'curPage': [3],
#   'keyword': ['UI设计师'],
#   'comtag': ['2018互联网300强']},
#  4: {'init': ['-1'],
#   'headckid': ['e8331dd1649d08f6'],
#   'fromSearchBtn': ['2'],
#   'compTag': ['182'],
#   'ckid': ['e8331dd1649d08f6°radeFlag=0'],
#   'key': ['UI设计师'],
#   'siTag': ['RPxWkfDdUaIMSr7n63Qw6w~fA9rXquZc5IkJpXC-Ycixw'],
#   'd_sfrom': ['search_unknown'],
#   'd_ckId': ['0be7c1359b8501734be78e445ef13b0f'],
#   'd_curPage': ['0'],
#   'd_pageSize': ['40'],
#   'd_headId': ['0be7c1359b8501734be78e445ef13b0f'],
#   'curPage': [4],
#   'keyword': ['UI设计师'],
#   'comtag': ['2018互联网300强']}}

# %%
import time
from random import random

# %%
# %%time
time.sleep(3+4*random())
# Out:
# Wall time: 5 s

# %%
# %%time

import time
from random import random

url = "https://www.liepin.com/zhaopin/?compTag=182&key=UI设计师"

keywords = ['UI设计师']
comtags = ['182：2018互联网300强']
list_df = list()


## 第一页试探有多长的页面
for key,com in zip(keywords, comtags):
    payload = 参数模板生成(keyword=[key], curPage=['0'],comtag = [com])
    df = requests_liepin( url, params = payload)
    href_列表 = [x.xpath('//@href')[0] for x in r.html.xpath(xpath_翻页a)]
    df = pd.DataFrame([ urlparse(x) for x in href_列表])
    df_qs = pd.DataFrame([{k:v[0] for k,v in parse_qs(x).items()} for x in df['query'] ])
    df_qs = df_qs.assign (curPage_int=df_qs.curPage.astype(int)) # 变成整数
    长度 = df_qs.curPage_int.max()+1
    

    
参数_keyword_X_curPage = { 
        i:参数模板生成(curPage = [i], \
                      keyword = [key],\
                       comtag = ['182'] ) \
                      
        for i in range(0,长度)\
        }
for k,v in 参数_keyword_X_curPage.items():
        payload = v
        df = requests_liepin( url, params = payload)
        time.sleep(3+4*random())  #放慢脚步 3-7秒, 平均约5秒
        
        df = df.assign (keyword = key)  
        df = df.assign (curPage = k)  
        df = df.assign (comtag = com) 
        list_df.append(df)
df_all = pd.concat(list_df).reset_index()
df_all.index.name = '序'

df_all.to_excel("web_2018互联网300强UI设计师.xlsx",\
                sheet_name="_".join(keywords))
# 预估时间: 4*5秒*10 =200
# 预估数量: 4*40*10 =1600
# Out:
# Wall time: 31.7 s
